# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w=np.load('model_weights.npy')

print(w.shape)
# Out:
# (1, 2500)

# %%
plt.plot(w[0,:100].T)

# %%
plt.hist(w[0,:], bins=100)
# Out:
# (array([ 2.,  0.,  0.,  1.,  6., 11.,  6.,  5., 16.,  9.,  9., 18., 16.,
#         13., 18., 21., 19., 27., 24., 21., 16., 18., 18., 29., 32., 31.,
#         30., 35., 33., 38., 40., 30., 33., 29., 36., 48., 27., 32., 44.,
#         22., 41., 45., 53., 46., 34., 51., 36., 39., 35., 44., 37., 24.,
#         27., 35., 50., 49., 33., 28., 45., 30., 39., 52., 37., 36., 34.,
#         41., 34., 30., 37., 33., 35., 28., 36., 25., 19., 28., 33., 20.,
#         19., 10., 22., 14., 25., 13., 20., 21., 16., 15., 14., 16., 13.,
#         16.,  5.,  8.,  4.,  5.,  1.,  0.,  0.,  1.]),
#  array([-0.02978575, -0.02918729, -0.02858882, -0.02799036, -0.0273919 ,
#         -0.02679344, -0.02619497, -0.02559651, -0.02499805, -0.02439958,
#         -0.02380112, -0.02320266, -0.0226042 , -0.02200573, -0.02140727,
#         -0.02080881, -0.02021034, -0.01961188, -0.01901342, -0.01841496,
#         -0.01781649, -0.01721803, -0.01661957, -0.0160211 , -0.01542264,
# ...
