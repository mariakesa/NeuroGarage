# Epoch [9700/10000], Loss: 0.3662
# Epoch [9710/10000], Loss: 0.3662
# Epoch [9720/10000], Loss: 0.3662
# Epoch [9730/10000], Loss: 0.3662
# Epoch [9740/10000], Loss: 0.3662
# Epoch [9750/10000], Loss: 0.3662
# Epoch [9760/10000], Loss: 0.3662
# Epoch [9770/10000], Loss: 0.3662
# Epoch [9780/10000], Loss: 0.3662
# Epoch [9790/10000], Loss: 0.3662
# Epoch [9800/10000], Loss: 0.3662
# Epoch [9810/10000], Loss: 0.3662
# Epoch [9820/10000], Loss: 0.3662
# Epoch [9830/10000], Loss: 0.3662
# Epoch [9840/10000], Loss: 0.3662
# Epoch [9850/10000], Loss: 0.3662
# Epoch [9860/10000], Loss: 0.3662
# Epoch [9870/10000], Loss: 0.3662
# Epoch [9880/10000], Loss: 0.3662
# Epoch [9890/10000], Loss: 0.3662
# Epoch [9900/10000], Loss: 0.3662
# Epoch [9910/10000], Loss: 0.3662
# Epoch [9920/10000], Loss: 0.3662
# Epoch [9930/10000], Loss: 0.3662
# Epoch [9940/10000], Loss: 0.3662
# Epoch [9950/10000], Loss: 0.3662
# Epoch [9960/10000], Loss: 0.3665
# Epoch [9970/10000], Loss: 0.3663
# Epoch [9980/10000], Loss: 0.3662
# Epoch [9990/10000], Loss: 0.3662
# Epoch [10000/10000], Loss: 0.3662
# Training finished

# %%
firing_rate, _=model(embeddings)

# %%
print(embeddings.shape)
# Out:
# torch.Size([900, 10])

# %%
import torch
def compute_fisher_information_hierarchical(model, embeddings, neuron_index=0, delta=0.0333):
    model.eval()  # Set model to evaluation mode
    
    # Ensure embeddings require gradients
    embeddings.requires_grad_(True)
    
    # Get firing rates and intermediate outputs
    firing_rate, _ = model(embeddings)  # Ignore x_0 for now
    firing_rate = firing_rate[:, neuron_index]  # Shape: (n_observations,)
    
    # Ensure firing rates are positive
    if torch.any(firing_rate <= 0):
        raise ValueError("Firing rates must be positive.")
    
    # Compute scaling factor if necessary
    scaled_firing_rate = firing_rate.detach() * delta  # Shape: (n_observations,)
    
    # Get parameters of the first linear layer
    params_theta1 = list(model.linear.parameters())
    num_params_theta1 = sum(p.numel() for p in params_theta1)
    print(f"Number of parameters in first layer: {num_params_theta1}")
    
    # Initialize gradient matrix
    gradients = torch.zeros((firing_rate.shape[0], num_params_theta1))
    
    # Compute gradients for each observation
    for i in range(firing_rate.shape[0]):
        model.zero_grad()
        # Compute scaled sqrt of firing rate
        sqrt_mu = torch.sqrt(scaled_firing_rate[i])
        # Backpropagate to get gradients
        (sqrt_mu * firing_rate[i]).backward(retain_graph=True)
        # Extract gradients
        grad_theta1 = []
        for param in params_theta1:
            grad_theta1.append(param.grad.detach().flatten())
        grad_theta1 = torch.cat(grad_theta1)
        gradients[i] = grad_theta1
    
    # Convert gradients to NumPy
    gradients_np = gradients.numpy()
    
    # Compute Fisher information matrix
    fisher_matrix = gradients_np.T @ gradients_np  # Shape: (num_params_theta1, num_params_theta1)
    
    print("Fisher information matrix shape:", fisher_matrix.shape)
    print("Fisher information matrix stats: min =", fisher_matrix.min(), 
          "max =", fisher_matrix.max(), "mean =", fisher_matrix.mean())
    
    # Check if Fisher matrix is positive semi-definite
    eigenvalues = np.linalg.eigvalsh(fisher_matrix)
    if np.any(eigenvalues < -1e-8):  # Allowing for small numerical errors
        print("Warning: Fisher information matrix has negative eigenvalues.")
    else:
        print("Fisher information matrix is positive semi-definite.")
    
    return fisher_matrix

compute_fisher_information_hierarchical(model, embeddings, neuron_index=0, delta=0.0333)
# Out:
# Number of parameters in first layer: 7690
# Fisher information matrix shape: (7690, 7690)
# Fisher information matrix stats: min = -569326.6 max = 884065.0 mean = 1.3651608
# Warning: Fisher information matrix has negative eigenvalues.
# array([[    8.426675 ,    -6.328634 ,    -5.6791945, ...,    21.515673 ,
#           -15.964235 ,   -11.584909 ],
#        [   -6.328634 ,   159.29916  ,    91.56505  , ...,  -740.5652   ,
#           549.4854   ,   398.7503   ],
#        [   -5.6791945,    91.56505  ,    62.043594 , ...,  -431.72702  ,
#           320.3333   ,   232.45941  ],
#        ...,
#        [   21.515673 ,  -740.5652   ,  -431.72702  , ...,  3546.4946   ,
#         -2631.432    , -1909.5764   ],
#        [  -15.964235 ,   549.4854   ,   320.3333   , ..., -2631.432    ,
#          1952.4733   ,  1416.8702   ],
#        [  -11.584909 ,   398.7503   ,   232.45941  , ..., -1909.5764   ,
#          1416.8702   ,  1028.1938   ]], dtype=float32)

# %%
fisher_matrix=FisherInformation(model, embeddings, neuron_index=0, delta=0.0333)
# Out:
# Firing rate shape: torch.Size([900, 657])
# take_neuron_0 shape: (900,)
# take_neuron_0 stats: min = 27.26111 max = 55.472095 mean = 40.54113
# Scaled firing rate stats: min = 0.907795 max = 1.8472209 mean = 1.3500196
# Fisher information matrix shape: (10, 10)
# Fisher information matrix stats: min = -324165.88 max = 472859.03 mean = 1154.0724
# Warning: Fisher information matrix has negative eigenvalues.

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt


def get_theta_hat_all_layers(model):
    """
    Extracts the parameters (weights and biases) from both linear layers of the model.

    Parameters:
    - model: Trained LNP model instance.

    Returns:
    - theta_hat: Estimated parameters as a numpy array.
    """
    with torch.no_grad():
        # First linear layer parameters
        weights1 = model.linear.weight.detach().numpy()  # Shape: (hidden_dim, input_dim)
        biases1 = model.linear.bias.detach().numpy()     # Shape: (hidden_dim,)

        # Second linear layer parameters
        weights2 = model.linear2.weight.detach().numpy()  # Shape: (n_neurons, hidden_dim)
        biases2 = model.linear2.bias.detach().numpy()     # Shape: (n_neurons,)

    # Flatten and concatenate all parameters into a single vector
    theta_hat = np.concatenate([
        weights1.flatten(),
        biases1,
        weights2.flatten(),
        biases2
    ])
    return theta_hat



def compute_fisher_information_all_layers(model, embeddings, neuron_index=0, delta=0.0333):
    model.eval()  # Set model to evaluation mode

    # Ensure embeddings require gradients
    embeddings.requires_grad_(True)

    # Get firing rates
    firing_rate, _ = model(embeddings)
    firing_rate = firing_rate[:, neuron_index]  # Shape: (n_observations,)

    # Ensure firing rates are positive
    if torch.any(firing_rate <= 0):
        raise ValueError("Firing rates must be positive.")

    # Compute scaling factor if necessary
    scaled_firing_rate = firing_rate.detach() * delta  # Shape: (n_observations,)

    # Get parameters of both linear layers
    params = list(model.linear.parameters()) + list(model.linear2.parameters())
    num_params = sum(p.numel() for p in params)
    print(f"Total number of parameters: {num_params}")

    # Initialize gradient matrix
    gradients = torch.zeros((firing_rate.shape[0], num_params))

    # Compute gradients for each observation
    for i in range(firing_rate.shape[0]):
        model.zero_grad()
        # Compute sqrt of scaled firing rate
        sqrt_mu = torch.sqrt(scaled_firing_rate[i])
        # Backpropagate to get gradients
        (sqrt_mu * firing_rate[i]).backward(retain_graph=True)
        # Extract gradients
        grad_params = []
        for param in params:
            grad_params.append(param.grad.detach().flatten())
        grad_params = torch.cat(grad_params)
        gradients[i] = grad_params

    # Convert gradients to NumPy
    gradients_np = gradients.numpy()

    # Compute Fisher information matrix
    fisher_matrix = gradients_np.T @ gradients_np  # Shape: (num_params, num_params)

    print("Fisher information matrix shape:", fisher_matrix.shape)
    print("Fisher information matrix stats: min =", fisher_matrix.min(),
          "max =", fisher_matrix.max(), "mean =", fisher_matrix.mean())

    # Check if Fisher matrix is positive semi-definite
    eigenvalues = np.linalg.eigvalsh(fisher_matrix)
    if np.any(eigenvalues < -1e-8):  # Allowing for small numerical errors
        print("Warning: Fisher information matrix has negative eigenvalues.")
    else:
        print("Fisher information matrix is positive semi-definite.")

    return fisher_matrix

def test_coefficients_significance(theta_hat, fisher_matrix, confidence_level=0.95):
    """
    Test the statistical significance of regression coefficients using the Fisher information matrix.

    Parameters:
    - theta_hat (numpy array): Estimated parameters (shape: p,)
    - fisher_matrix (numpy array): Fisher information matrix (shape: p, p)
    - confidence_level (float): Desired confidence level (default: 0.95)

    Returns:
    - results (list of dict): Each dict contains parameter index, estimate, standard error, z-score, p-value, and significance
    """
    # Step 1: Compute Covariance Matrix
    try:
        cov_matrix = np.linalg.inv(fisher_matrix)
    except np.linalg.LinAlgError:
        # Regularize the Fisher information matrix if it's singular
        print("Fisher information matrix is singular or ill-conditioned. Adding a small value to the diagonal for regularization.")
        regularization_term = 1e-8 * np.eye(fisher_matrix.shape[0])
        cov_matrix = np.linalg.inv(fisher_matrix + regularization_term)

    # Step 2: Compute Standard Errors
    standard_errors = np.sqrt(np.diag(cov_matrix))

    # Avoid division by zero in standard errors
    standard_errors = np.where(standard_errors == 0, 1e-8, standard_errors)

    # Step 3: Compute Z-scores
    z_scores = theta_hat / standard_errors

    # Step 4: Compute P-values
    p_values = 2 * (1 - norm.cdf(np.abs(z_scores)))

    # Step 5: Assess Significance
    alpha = 1 - confidence_level
    significant = p_values < alpha

    # Compile Results
    results = []
    for idx, (theta, se, z, p, sig) in enumerate(zip(theta_hat, standard_errors, z_scores, p_values, significant)):
        result = {
            'Parameter Index': idx,
            'Estimate': theta,
            'Standard Error': se,
            'Z-score': z,
            'P-value': p,
            f'Significant at {int(confidence_level*100)}%': sig
        }
        results.append(result)

    return results




theta_hat=get_theta_hat_all_layers(model)
fisher_matrix=compute_fisher_information_all_layers(model, embeddings, neuron_index=0, delta=0.0333)
test_coefficients_significance(theta_hat, fisher_matrix, confidence_level=0.95)
# Out:
# Total number of parameters: 14917
# Fisher information matrix shape: (14917, 14917)
# Fisher information matrix stats: min = -565847200.0 max = 827506750.0 mean = 2.0512176
# Warning: Fisher information matrix has negative eigenvalues.
# Fisher information matrix is singular or ill-conditioned. Adding a small value to the diagonal for regularization.
# /tmp/ipykernel_1677307/2076510044.py:116: RuntimeWarning: invalid value encountered in sqrt
#   standard_errors = np.sqrt(np.diag(cov_matrix))
# [{'Parameter Index': 0,
#   'Estimate': 0.011454333,
#   'Standard Error': 178.11867070810135,
#   'Z-score': 6.430731025764665e-05,
#   'P-value': 0.9999486901900341,
#   'Significant at 95%': False},
#  {'Parameter Index': 1,
#   'Estimate': -0.0063936855,
#   'Standard Error': 28.7083370623135,
#   'Z-score': -0.00022271180171072103,
#   'P-value': 0.9998223016933754,
#   'Significant at 95%': False},
#  {'Parameter Index': 2,
#   'Estimate': 0.000749979,
#   'Standard Error': 32.22849884026737,
#   'Z-score': 2.32706772124496e-05,
#   'P-value': 0.9999814326859344,
#   'Significant at 95%': False},
#  {'Parameter Index': 3,
#   'Estimate': -0.040409014,
#   'Standard Error': 43.411008444708294,
#   'Z-score': -0.0009308471532152446,
#   'P-value': 0.9992572915352389,
#   'Significant at 95%': False},
#  {'Parameter Index': 4,
#   'Estimate': -0.044286657,
#   'Standard Error': 87.3998521220371,
#   'Z-score': -0.0005067131814241511,
#   'P-value': 0.9995957013930876,
#   'Significant at 95%': False},
#  {'Parameter Index': 5,
#   'Estimate': -0.01440253,
#   'Standard Error': 52.522248585310784,
#   'Z-score': -0.0002742176990515215,
#   'P-value': 0.99978120593437,
#   'Significant at 95%': False},
#  {'Parameter Index': 6,
#   'Estimate': -0.0015868108,
#   'Standard Error': 58.80570429496747,
#   'Z-score': -2.6983960504072002e-05,
#   'P-value': 0.9999784699145271,
#   'Significant at 95%': False},
#  {'Parameter Index': 7,
#   'Estimate': -0.0045173033,
#   'Standard Error': 54.893552262091944,
#   'Z-score': -8.229205667893176e-05,
#   'P-value': 0.9999343404385732,
#   'Significant at 95%': False},
#  {'Parameter Index': 8,
#   'Estimate': 0.009108763,
#   'Standard Error': 17.440588849253004,
#   'Z-score': 0.0005222738330027107,
#   'P-value': 0.9995832857910802,
#   'Significant at 95%': False},
#  {'Parameter Index': 9,
#   'Estimate': 0.0035121855,
#   'Standard Error': 68.71173315070212,
#   'Z-score': 5.1114785955065074e-05,
#   'P-value': 0.9999592163014754,
#   'Significant at 95%': False},
#  {'Parameter Index': 10,
#   'Estimate': -0.0005103864,
#   'Standard Error': 247.7172231970878,
#   'Z-score': -2.060359055991316e-06,
#   'P-value': 0.9999983560713195,
#   'Significant at 95%': False},
#  {'Parameter Index': 11,
#   'Estimate': 0.01407316,
#   'Standard Error': 73.45746868472915,
#   'Z-score': 0.00019158241901936986,
#   'P-value': 0.9998471393466783,
#   'Significant at 95%': False},
#  {'Parameter Index': 12,
#   'Estimate': -0.0052548726,
#   'Standard Error': 115.60449260596178,
#   'Z-score': -4.545560895147146e-05,
#   'P-value': 0.9999637316714283,
#   'Significant at 95%': False},
#  {'Parameter Index': 13,
#   'Estimate': 0.0061788526,
#   'Standard Error': 79.40056583935656,
#   'Z-score': 7.781874815436648e-05,
#   'P-value': 0.9999379096223693,
#   'Significant at 95%': False},
#  {'Parameter Index': 14,
#   'Estimate': 0.0017946961,
#   'Standard Error': 24.971526629359392,
#   'Z-score': 7.186969838310185e-05,
#   'P-value': 0.9999426562773199,
#   'Significant at 95%': False},
#  {'Parameter Index': 15,
#   'Estimate': -0.027472101,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 16,
#   'Estimate': 0.034828234,
#   'Standard Error': 16.369650782581502,
#   'Z-score': 0.002127610107662767,
#   'P-value': 0.9983024140244385,
#   'Significant at 95%': False},
#  {'Parameter Index': 17,
#   'Estimate': -0.009876963,
#   'Standard Error': 55.96363544406276,
#   'Z-score': -0.0001764889409484921,
#   'P-value': 0.9998591821995957,
#   'Significant at 95%': False},
#  {'Parameter Index': 18,
#   'Estimate': -0.0165294,
#   'Standard Error': 109.8241093960039,
#   'Z-score': -0.00015050793484722708,
#   'P-value': 0.9998799120429605,
#   'Significant at 95%': False},
#  {'Parameter Index': 19,
#   'Estimate': 0.0072259605,
#   'Standard Error': 92.96394216265472,
#   'Z-score': 7.772863677020967e-05,
#   'P-value': 0.9999379815208513,
#   'Significant at 95%': False},
#  {'Parameter Index': 20,
#   'Estimate': 0.018095119,
#   'Standard Error': 147.8275318548924,
#   'Z-score': 0.0001224069609897673,
#   'P-value': 0.9999023333759354,
#   'Significant at 95%': False},
#  {'Parameter Index': 21,
#   'Estimate': -0.020810539,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 22,
#   'Estimate': 0.00042999824,
#   'Standard Error': 50.09159156217207,
#   'Z-score': 8.584239906527628e-06,
#   'P-value': 0.9999931507675124,
#   'Significant at 95%': False},
#  {'Parameter Index': 23,
#   'Estimate': -0.013426156,
#   'Standard Error': 27.549856257347532,
#   'Z-score': -0.00048734032068335303,
#   'P-value': 0.9996111586976617,
#   'Significant at 95%': False},
#  {'Parameter Index': 24,
#   'Estimate': 0.0045672,
#   'Standard Error': 160.99741084913774,
#   'Z-score': 2.8368157153764764e-05,
#   'P-value': 0.9999773654853916,
#   'Significant at 95%': False},
#  {'Parameter Index': 25,
#   'Estimate': -0.02670306,
#   'Standard Error': 69.05190962442937,
#   'Z-score': -0.00038670993776343364,
#   'P-value': 0.9996914501188399,
#   'Significant at 95%': False},
#  {'Parameter Index': 26,
#   'Estimate': 0.03175286,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 27,
#   'Estimate': 0.0015011774,
#   'Standard Error': 53.73692452325293,
#   'Z-score': 2.7935678324015124e-05,
#   'P-value': 0.9999777105535725,
#   'Significant at 95%': False},
#  {'Parameter Index': 28,
#   'Estimate': -0.01961633,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 29,
#   'Estimate': 0.011546669,
#   'Standard Error': 38.215525353464265,
#   'Z-score': 0.000302146012380254,
#   'P-value': 0.9997589223652816,
#   'Significant at 95%': False},
#  {'Parameter Index': 30,
#   'Estimate': 0.015497675,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 31,
#   'Estimate': 0.015906423,
#   'Standard Error': 27.78356519216921,
#   'Z-score': 0.000572511958788868,
#   'P-value': 0.9995432015721615,
#   'Significant at 95%': False},
#  {'Parameter Index': 32,
#   'Estimate': 0.00997523,
#   'Standard Error': 54.37358190673374,
#   'Z-score': 0.000183457296199439,
#   'P-value': 0.999853622256617,
#   'Significant at 95%': False},
#  {'Parameter Index': 33,
#   'Estimate': 0.012932455,
#   'Standard Error': 65.90478166940555,
#   'Z-score': 0.00019622939094232473,
#   'P-value': 0.9998434315995961,
#   'Significant at 95%': False},
#  {'Parameter Index': 34,
#   'Estimate': 0.0064120404,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 35,
#   'Estimate': -0.020362185,
#   'Standard Error': 41.50542686655494,
#   'Z-score': -0.000490590914286091,
#   'P-value': 0.9996085650995228,
#   'Significant at 95%': False},
#  {'Parameter Index': 36,
#   'Estimate': -0.00397161,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 37,
#   'Estimate': -0.027519718,
#   'Standard Error': 103.10776498576799,
#   'Z-score': -0.00026690247641714186,
#   'P-value': 0.9997870426373552,
#   'Significant at 95%': False},
#  {'Parameter Index': 38,
#   'Estimate': 0.0020382302,
#   'Standard Error': 33.48443544934153,
#   'Z-score': 6.087097365803187e-05,
#   'P-value': 0.9999514319899472,
#   'Significant at 95%': False},
#  {'Parameter Index': 39,
#   'Estimate': 0.0078224065,
#   'Standard Error': 66.90736147412338,
#   'Z-score': 0.00011691398832476041,
#   'P-value': 0.9999067161339863,
#   'Significant at 95%': False},
#  {'Parameter Index': 40,
#   'Estimate': 0.017394014,
#   'Standard Error': 26.94600732539908,
#   'Z-score': 0.000645513581764448,
#   'P-value': 0.9994849547150904,
#   'Significant at 95%': False},
#  {'Parameter Index': 41,
#   'Estimate': -0.016769145,
#   'Standard Error': 146.6526098528356,
#   'Z-score': -0.00011434603653425584,
#   'P-value': 0.9999087650630591,
#   'Significant at 95%': False},
#  {'Parameter Index': 42,
#   'Estimate': -0.020108849,
#   'Standard Error': 74.89513767981674,
#   'Z-score': -0.0002684933819891354,
#   'P-value': 0.999785773278407,
#   'Significant at 95%': False},
#  {'Parameter Index': 43,
#   'Estimate': -6.91829e-05,
#   'Standard Error': 69.20743893911018,
#   'Z-score': -9.99645389833169e-07,
#   'P-value': 0.9999992023983773,
#   'Significant at 95%': False},
#  {'Parameter Index': 44,
#   'Estimate': 0.013845849,
#   'Standard Error': 42.869468279564195,
#   'Z-score': 0.00032297692055831235,
#   'P-value': 0.9997423017060711,
#   'Significant at 95%': False},
#  {'Parameter Index': 45,
#   'Estimate': -0.010093038,
#   'Standard Error': 47.84887133350476,
#   'Z-score': -0.00021093575854728137,
#   'P-value': 0.9998316976161818,
#   'Significant at 95%': False},
#  {'Parameter Index': 46,
#   'Estimate': -0.01938138,
#   'Standard Error': 65.81997784809778,
#   'Z-score': -0.00029446044107424226,
#   'P-value': 0.9997650545636949,
#   'Significant at 95%': False},
#  {'Parameter Index': 47,
#   'Estimate': -0.010395446,
#   'Standard Error': 170.86256136234536,
#   'Z-score': -6.084098106709807e-05,
#   'P-value': 0.9999514559205724,
#   'Significant at 95%': False},
#  {'Parameter Index': 48,
#   'Estimate': 0.009320392,
#   'Standard Error': 12.26848935320895,
#   'Z-score': 0.0007597017045076218,
#   'P-value': 0.9993938457974645,
#   'Significant at 95%': False},
#  {'Parameter Index': 49,
#   'Estimate': 0.001490986,
#   'Standard Error': 55.150143815400256,
#   'Z-score': 2.703503330218171e-05,
#   'P-value': 0.9999784291643301,
#   'Significant at 95%': False},
#  {'Parameter Index': 50,
#   'Estimate': 0.007173908,
#   'Standard Error': 135.7712946700961,
#   'Z-score': 5.28381787954623e-05,
#   'P-value': 0.9999578412329377,
#   'Significant at 95%': False},
#  {'Parameter Index': 51,
#   'Estimate': -0.007585715,
#   'Standard Error': 82.15844754536957,
#   'Z-score': -9.233031128844372e-05,
#   'P-value': 0.9999263310702335,
#   'Significant at 95%': False},
#  {'Parameter Index': 52,
#   'Estimate': -0.0009969288,
#   'Standard Error': 37.38233093348193,
#   'Z-score': -2.666844879873721e-05,
#   'P-value': 0.9999787216564455,
#   'Significant at 95%': False},
#  {'Parameter Index': 53,
#   'Estimate': 0.005469758,
#   'Standard Error': 77.37260642326552,
#   'Z-score': 7.069372891010736e-05,
#   'P-value': 0.999943594565204,
#   'Significant at 95%': False},
#  {'Parameter Index': 54,
#   'Estimate': -0.00087095296,
#   'Standard Error': 51.42343807613089,
#   'Z-score': -1.6936887095548584e-05,
#   'P-value': 0.9999864863192791,
#   'Significant at 95%': False},
#  {'Parameter Index': 55,
#   'Estimate': 0.017993737,
#   'Standard Error': 71.40707859899493,
#   'Z-score': 0.00025198814130453966,
#   'P-value': 0.9997989425546754,
#   'Significant at 95%': False},
#  {'Parameter Index': 56,
#   'Estimate': -0.021654563,
#   'Standard Error': 49.0794590701985,
#   'Z-score': -0.00044121437837502434,
#   'P-value': 0.9996479618709122,
#   'Significant at 95%': False},
#  {'Parameter Index': 57,
#   'Estimate': 0.008187439,
#   'Standard Error': 27.558686606188317,
#   'Z-score': 0.00029709105552333553,
#   'P-value': 0.9997629556371324,
#   'Significant at 95%': False},
#  {'Parameter Index': 58,
#   'Estimate': -0.0057332185,
#   'Standard Error': 7.903731826622973,
#   'Z-score': -0.0007253812041537227,
#   'P-value': 0.9994212295872651,
#   'Significant at 95%': False},
#  {'Parameter Index': 59,
#   'Estimate': 0.016509162,
#   'Standard Error': 55.971294266769576,
#   'Z-score': 0.00029495766496655175,
#   'P-value': 0.9997646578364452,
#   'Significant at 95%': False},
#  {'Parameter Index': 60,
#   'Estimate': 0.015952317,
#   'Standard Error': 238.0783894854798,
#   'Z-score': 6.700447310070462e-05,
#   'P-value': 0.9999465381654482,
#   'Significant at 95%': False},
#  {'Parameter Index': 61,
#   'Estimate': -0.0042146067,
#   'Standard Error': 49.35408542096199,
#   'Z-score': -8.53952955982352e-05,
#   'P-value': 0.9999318644121598,
#   'Significant at 95%': False},
#  {'Parameter Index': 62,
#   'Estimate': 0.0065418584,
#   'Standard Error': 49.08702999706915,
#   'Z-score': 0.00013327060992724839,
#   'P-value': 0.9998936654382451,
#   'Significant at 95%': False},
#  {'Parameter Index': 63,
#   'Estimate': 0.01241219,
#   'Standard Error': 43.170491297183155,
#   'Z-score': 0.0002875156169030391,
#   'P-value': 0.999770595731444,
#   'Significant at 95%': False},
#  {'Parameter Index': 64,
#   'Estimate': -0.008863925,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 65,
#   'Estimate': -0.006979375,
#   'Standard Error': 26.46560845153314,
#   'Z-score': -0.00026371489471367475,
#   'P-value': 0.9997895859594932,
#   'Significant at 95%': False},
#  {'Parameter Index': 66,
#   'Estimate': -0.0055214064,
#   'Standard Error': 96.03168334629271,
#   'Z-score': -5.7495674627142396e-05,
#   'P-value': 0.9999541250889272,
#   'Significant at 95%': False},
#  {'Parameter Index': 67,
#   'Estimate': 0.0034895155,
#   'Standard Error': 203.28261488528184,
#   'Z-score': 1.716583345451491e-05,
#   'P-value': 0.999986303646514,
#   'Significant at 95%': False},
#  {'Parameter Index': 68,
#   'Estimate': -0.010060796,
#   'Standard Error': 44.36736824651002,
#   'Z-score': -0.0002267611530828696,
#   'P-value': 0.999819070778516,
#   'Significant at 95%': False},
#  {'Parameter Index': 69,
#   'Estimate': 0.015325742,
#   'Standard Error': 79.96225497829745,
#   'Z-score': 0.00019166220170439998,
#   'P-value': 0.9998470756893068,
#   'Significant at 95%': False},
#  {'Parameter Index': 70,
#   'Estimate': 0.015001146,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 71,
#   'Estimate': -0.012526148,
#   'Standard Error': 147.0984140894823,
#   'Z-score': -8.515488135208286e-05,
#   'P-value': 0.9999320562349743,
#   'Significant at 95%': False},
#  {'Parameter Index': 72,
#   'Estimate': -0.014242389,
#   'Standard Error': 169.91379109355304,
#   'Z-score': -8.382126693606105e-05,
#   'P-value': 0.999933120305323,
#   'Significant at 95%': False},
#  {'Parameter Index': 73,
#   'Estimate': -0.007827562,
#   'Standard Error': 140.089380690482,
#   'Z-score': -5.587548636033823e-05,
#   'P-value': 0.999955417812129,
#   'Significant at 95%': False},
#  {'Parameter Index': 74,
#   'Estimate': -0.0031559574,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 75,
#   'Estimate': -0.009346718,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 76,
#   'Estimate': -0.00048656057,
#   'Standard Error': 141.21049184403134,
#   'Z-score': -3.4456403839535445e-06,
#   'P-value': 0.9999972507767356,
#   'Significant at 95%': False},
#  {'Parameter Index': 77,
#   'Estimate': 0.014900336,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 78,
#   'Estimate': -0.01432203,
#   'Standard Error': 41.547493696026976,
#   'Z-score': -0.0003447146646871277,
#   'P-value': 0.9997249574966109,
#   'Significant at 95%': False},
#  {'Parameter Index': 79,
#   'Estimate': 0.011303358,
#   'Standard Error': 240.23128576167954,
#   'Z-score': 4.705198052843606e-05,
#   'P-value': 0.999962457951195,
#   'Significant at 95%': False},
#  {'Parameter Index': 80,
#   'Estimate': -0.0038877171,
#   'Standard Error': 53.3133048311449,
#   'Z-score': -7.292208124669263e-05,
#   'P-value': 0.9999418165972833,
#   'Significant at 95%': False},
#  {'Parameter Index': 81,
#   'Estimate': -0.0062631606,
#   'Standard Error': 45.932179280366306,
#   'Z-score': -0.0001363567048322337,
#   'P-value': 0.9998912030907896,
#   'Significant at 95%': False},
#  {'Parameter Index': 82,
#   'Estimate': 0.000917467,
#   'Standard Error': 38.6035765098486,
#   'Z-score': 2.3766372978435144e-05,
#   'P-value': 0.9999810371779361,
#   'Significant at 95%': False},
#  {'Parameter Index': 83,
#   'Estimate': -0.011962291,
#   'Standard Error': 30.485347028157914,
#   'Z-score': -0.0003923947738634213,
#   'P-value': 0.9996869142762292,
#   'Significant at 95%': False},
#  {'Parameter Index': 84,
#   'Estimate': -0.0061047315,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 85,
#   'Estimate': 0.016275676,
#   'Standard Error': 91.7747461977649,
#   'Z-score': 0.00017734373170875717,
#   'P-value': 0.9998585001752562,
#   'Significant at 95%': False},
#  {'Parameter Index': 86,
#   'Estimate': 0.026420452,
#   'Standard Error': 39.06749295108965,
#   'Z-score': 0.0006762771221015989,
#   'P-value': 0.9994604089665813,
#   'Significant at 95%': False},
#  {'Parameter Index': 87,
#   'Estimate': 0.0019105737,
#   'Standard Error': 110.29001925806513,
#   'Z-score': 1.7323178464613042e-05,
#   'P-value': 0.9999861781033597,
#   'Significant at 95%': False},
#  {'Parameter Index': 88,
#   'Estimate': 0.008790764,
#   'Standard Error': 69.73945663643855,
#   'Z-score': 0.00012605151302183632,
#   'P-value': 0.9998994254441604,
#   'Significant at 95%': False},
#  {'Parameter Index': 89,
#   'Estimate': 0.00042059214,
#   'Standard Error': 80.45715139406177,
#   'Z-score': 5.227529634256728e-06,
#   'P-value': 0.9999958290348137,
#   'Significant at 95%': False},
#  {'Parameter Index': 90,
#   'Estimate': -0.0152507825,
#   'Standard Error': 100.25571896191275,
#   'Z-score': -0.00015211882813507944,
#   'P-value': 0.9998786267360917,
#   'Significant at 95%': False},
#  {'Parameter Index': 91,
#   'Estimate': -0.02587082,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 92,
#   'Estimate': -0.002699069,
#   'Standard Error': 15.456895037488792,
#   'Z-score': -0.00017461909223975624,
#   'P-value': 0.9998606741229885,
#   'Significant at 95%': False},
#  {'Parameter Index': 93,
#   'Estimate': 0.0063121496,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 94,
#   'Estimate': -0.0027080444,
#   'Standard Error': 32.01574623796501,
#   'Z-score': -8.458476490429067e-05,
#   'P-value': 0.9999325111220843,
#   'Significant at 95%': False},
#  {'Parameter Index': 95,
#   'Estimate': -0.0014719211,
#   'Standard Error': 100.10462969665272,
#   'Z-score': -1.4703826461728218e-05,
#   'P-value': 0.9999882680438819,
#   'Significant at 95%': False},
#  {'Parameter Index': 96,
#   'Estimate': 0.0067805904,
#   'Standard Error': 17.445677895527023,
#   'Z-score': 0.00038866878300630384,
#   'P-value': 0.9996898871865809,
#   'Significant at 95%': False},
#  {'Parameter Index': 97,
#   'Estimate': 0.0020917691,
#   'Standard Error': 27.675705961130053,
#   'Z-score': 7.55814190241688e-05,
#   'P-value': 0.9999396947527344,
#   'Significant at 95%': False},
#  {'Parameter Index': 98,
#   'Estimate': 0.018987838,
#   'Standard Error': 82.37334307415857,
#   'Z-score': 0.0002305095006497285,
#   'P-value': 0.999816080029942,
#   'Significant at 95%': False},
#  {'Parameter Index': 99,
#   'Estimate': 0.015520081,
#   'Standard Error': 13.395327959487986,
#   'Z-score': 0.0011586189581152553,
#   'P-value': 0.9990755560282949,
#   'Significant at 95%': False},
#  {'Parameter Index': 100,
#   'Estimate': -0.00046258772,
#   'Standard Error': 153.915043215324,
#   'Z-score': -3.005474380028885e-06,
#   'P-value': 0.9999976019783943,
#   'Significant at 95%': False},
#  {'Parameter Index': 101,
#   'Estimate': -0.0034141426,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 102,
#   'Estimate': 0.020675372,
#   'Standard Error': 25.0765109284403,
#   'Z-score': 0.0008244915886159318,
#   'P-value': 0.9993421509654643,
#   'Significant at 95%': False},
#  {'Parameter Index': 103,
#   'Estimate': -0.011116783,
#   'Standard Error': 27.753939826915452,
#   'Z-score': -0.00040054792955407126,
#   'P-value': 0.9996804089996931,
#   'Significant at 95%': False},
#  {'Parameter Index': 104,
#   'Estimate': 0.003833004,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 105,
#   'Estimate': -0.017199319,
#   'Standard Error': 27.432024823320013,
#   'Z-score': -0.0006269795600862729,
#   'P-value': 0.9994997427218437,
#   'Significant at 95%': False},
#  {'Parameter Index': 106,
#   'Estimate': -0.0051466203,
#   'Standard Error': 134.28305930414447,
#   'Z-score': -3.8326653832130844e-05,
#   'P-value': 0.9999694197546476,
#   'Significant at 95%': False},
#  {'Parameter Index': 107,
#   'Estimate': -0.015698608,
#   'Standard Error': 118.34551149286656,
#   'Z-score': -0.0001326506414394395,
#   'P-value': 0.9998941601015252,
#   'Significant at 95%': False},
#  {'Parameter Index': 108,
#   'Estimate': 0.022855688,
#   'Standard Error': 113.78568473937094,
#   'Z-score': 0.00020086611016867424,
#   'P-value': 0.9998397320329857,
#   'Significant at 95%': False},
#  {'Parameter Index': 109,
#   'Estimate': 0.011571039,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 110,
#   'Estimate': 0.024972957,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 111,
#   'Estimate': 0.0031794354,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 112,
#   'Estimate': -0.0033069071,
#   'Standard Error': 227.3517686412081,
#   'Z-score': -1.4545332793130761e-05,
#   'P-value': 0.999988394503533,
#   'Significant at 95%': False},
#  {'Parameter Index': 113,
#   'Estimate': 0.012805264,
#   'Standard Error': 9.394614579062733,
#   'Z-score': 0.0013630430855244983,
#   'P-value': 0.9989124493031085,
#   'Significant at 95%': False},
#  {'Parameter Index': 114,
#   'Estimate': -0.01151573,
#   'Standard Error': 6.400371593534257,
#   'Z-score': -0.0017992283560958155,
#   'P-value': 0.9985644242478589,
#   'Significant at 95%': False},
#  {'Parameter Index': 115,
#   'Estimate': 0.021173418,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 116,
#   'Estimate': 0.00745948,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 117,
#   'Estimate': 0.047666203,
#   'Standard Error': 1.5326326294430554,
#   'Z-score': 0.03110086677975849,
#   'P-value': 0.9751890984149398,
#   'Significant at 95%': False},
#  {'Parameter Index': 118,
#   'Estimate': -0.027352192,
#   'Standard Error': 97.1607840147947,
#   'Z-score': -0.00028151472618470624,
#   'P-value': 0.9997753837493053,
#   'Significant at 95%': False},
#  {'Parameter Index': 119,
#   'Estimate': 0.0013440957,
#   'Standard Error': 74.50311036993115,
#   'Z-score': 1.8040799586103942e-05,
#   'P-value': 0.9999856055245464,
#   'Significant at 95%': False},
#  {'Parameter Index': 120,
#   'Estimate': -0.016032664,
#   'Standard Error': 66.89431021574904,
#   'Z-score': -0.00023967156628997629,
#   'P-value': 0.9998087697594247,
#   'Significant at 95%': False},
#  {'Parameter Index': 121,
#   'Estimate': -0.0062803244,
#   'Standard Error': 348.4373593676838,
#   'Z-score': -1.8024256736476404e-05,
#   'P-value': 0.9999856187238307,
#   'Significant at 95%': False},
#  {'Parameter Index': 122,
#   'Estimate': 0.0015408646,
#   'Standard Error': 41.80761056126264,
#   'Z-score': 3.685607869671464e-05,
#   'P-value': 0.9999705931038427,
#   'Significant at 95%': False},
#  {'Parameter Index': 123,
#   'Estimate': 0.02161154,
#   'Standard Error': 32.87578993648915,
#   'Z-score': 0.0006573694408174904,
#   'P-value': 0.9994754951102043,
#   'Significant at 95%': False},
#  {'Parameter Index': 124,
#   'Estimate': 0.007492445,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 125,
#   'Estimate': -0.0070677283,
#   'Standard Error': 96.55815020068174,
#   'Z-score': -7.319660025911941e-05,
#   'P-value': 0.9999415975628021,
#   'Significant at 95%': False},
#  {'Parameter Index': 126,
#   'Estimate': 0.026006011,
#   'Standard Error': 41.99380257827868,
#   'Z-score': 0.0006192821248769216,
#   'P-value': 0.9995058843853626,
#   'Significant at 95%': False},
#  {'Parameter Index': 127,
#   'Estimate': -0.0023076255,
#   'Standard Error': 14.003922742499096,
#   'Z-score': -0.00016478422009881592,
#   'P-value': 0.9998685212155143,
#   'Significant at 95%': False},
#  {'Parameter Index': 128,
#   'Estimate': 0.00025408273,
#   'Standard Error': 21.95136273726421,
#   'Z-score': 1.157480423223739e-05,
#   'P-value': 0.9999907646424089,
#   'Significant at 95%': False},
#  {'Parameter Index': 129,
#   'Estimate': 0.019579628,
#   'Standard Error': 91.54026329404662,
#   'Z-score': 0.00021389089104503753,
#   'P-value': 0.99982933976164,
#   'Significant at 95%': False},
#  {'Parameter Index': 130,
#   'Estimate': -0.0102449525,
#   'Standard Error': 130.90339100605172,
#   'Z-score': -7.826346159584222e-05,
#   'P-value': 0.9999375547923814,
#   'Significant at 95%': False},
#  {'Parameter Index': 131,
#   'Estimate': -0.00278078,
#   'Standard Error': 139.80813092416358,
#   'Z-score': -1.9889973100832175e-05,
#   'P-value': 0.9999841300975492,
#   'Significant at 95%': False},
#  {'Parameter Index': 132,
#   'Estimate': 0.0030297148,
#   'Standard Error': 70.30073872629764,
#   'Z-score': 4.309648602610456e-05,
#   'P-value': 0.9999656139791855,
#   'Significant at 95%': False},
#  {'Parameter Index': 133,
#   'Estimate': -0.010211884,
#   'Standard Error': 60.48085330004553,
#   'Z-score': -0.00016884490689060908,
#   'P-value': 0.9998652812562618,
#   'Significant at 95%': False},
#  {'Parameter Index': 134,
#   'Estimate': 0.0021263186,
#   'Standard Error': 55.58921795405136,
#   'Z-score': 3.825055853774688e-05,
#   'P-value': 0.9999694804699082,
#   'Significant at 95%': False},
#  {'Parameter Index': 135,
#   'Estimate': 0.015760968,
#   'Standard Error': 43.08093443461017,
#   'Z-score': 0.0003658455350331593,
#   'P-value': 0.9997080975024699,
#   'Significant at 95%': False},
#  {'Parameter Index': 136,
#   'Estimate': -0.0066229976,
#   'Standard Error': 34.347491930010044,
#   'Z-score': -0.00019282332438505778,
#   'P-value': 0.999846149247464,
#   'Significant at 95%': False},
#  {'Parameter Index': 137,
#   'Estimate': -0.013597696,
#   'Standard Error': 74.63639890317783,
#   'Z-score': -0.0001821858541955391,
#   'P-value': 0.9998546367205448,
#   'Significant at 95%': False},
#  {'Parameter Index': 138,
#   'Estimate': -0.004581114,
#   'Standard Error': 23.32409553475806,
#   'Z-score': -0.0001964112093759629,
#   'P-value': 0.999843286529478,
#   'Significant at 95%': False},
#  {'Parameter Index': 139,
#   'Estimate': 0.011099397,
#   'Standard Error': 64.91200990272633,
#   'Z-score': 0.0001709914270325215,
#   'P-value': 0.999863568581006,
#   'Significant at 95%': False},
#  {'Parameter Index': 140,
#   'Estimate': -0.014287027,
#   'Standard Error': 49.6456913029074,
#   'Z-score': -0.00028777978962723957,
#   'P-value': 0.9997703849521147,
#   'Significant at 95%': False},
#  {'Parameter Index': 141,
#   'Estimate': -0.002864472,
#   'Standard Error': 110.02779433373273,
#   'Z-score': -2.6034077295827767e-05,
#   'P-value': 0.9999792278116733,
#   'Significant at 95%': False},
#  {'Parameter Index': 142,
#   'Estimate': -0.00048020275,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 143,
#   'Estimate': -0.0026565543,
#   'Standard Error': 69.82554543917723,
#   'Z-score': -3.80455937849418e-05,
#   'P-value': 0.9999696440081198,
#   'Significant at 95%': False},
#  {'Parameter Index': 144,
#   'Estimate': 0.015532219,
#   'Standard Error': 44.580379383717016,
#   'Z-score': 0.0003484093017122736,
#   'P-value': 0.9997220096029478,
#   'Significant at 95%': False},
#  {'Parameter Index': 145,
#   'Estimate': 0.0011686217,
#   'Standard Error': 81.66473623713975,
#   'Z-score': 1.4309991776485818e-05,
#   'P-value': 0.9999885822784966,
#   'Significant at 95%': False},
#  {'Parameter Index': 146,
#   'Estimate': -0.013267599,
#   'Standard Error': 45.120217314548874,
#   'Z-score': -0.00029404998104812366,
#   'P-value': 0.9997653820633985,
#   'Significant at 95%': False},
#  {'Parameter Index': 147,
#   'Estimate': 0.00010306809,
#   'Standard Error': 28.244777296997928,
#   'Z-score': 3.6491024806806736e-06,
#   'P-value': 0.9999970884374698,
#   'Significant at 95%': False},
#  {'Parameter Index': 148,
#   'Estimate': -0.0008325914,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 149,
#   'Estimate': 0.006090671,
#   'Standard Error': 28.98258039357101,
#   'Z-score': 0.0002101493635605321,
#   'P-value': 0.9998323250685868,
#   'Significant at 95%': False},
#  {'Parameter Index': 150,
#   'Estimate': -0.0015077074,
#   'Standard Error': 35.92165806358938,
#   'Z-score': -4.1972099482891635e-05,
#   'P-value': 0.9999665111098479,
#   'Significant at 95%': False},
#  {'Parameter Index': 151,
#   'Estimate': -0.004309084,
#   'Standard Error': 108.59776618201816,
#   'Z-score': -3.9679304209080483e-05,
#   'P-value': 0.9999683404957964,
#   'Significant at 95%': False},
#  {'Parameter Index': 152,
#   'Estimate': 0.014171526,
#   'Standard Error': 32.55433907663281,
#   'Z-score': 0.0004353191076197609,
#   'P-value': 0.9996526656159779,
#   'Significant at 95%': False},
#  {'Parameter Index': 153,
#   'Estimate': -0.020200511,
#   'Standard Error': 110.73688969936134,
#   'Z-score': -0.00018241898878934497,
#   'P-value': 0.9998544507060549,
#   'Significant at 95%': False},
#  {'Parameter Index': 154,
#   'Estimate': -0.006195883,
#   'Standard Error': 132.72271712412737,
#   'Z-score': -4.6682911073707706e-05,
#   'P-value': 0.9999627524260144,
#   'Significant at 95%': False},
#  {'Parameter Index': 155,
#   'Estimate': -0.002757085,
#   'Standard Error': 15.432819122206894,
#   'Z-score': -0.00017865077013816272,
#   'P-value': 0.9998574573094894,
#   'Significant at 95%': False},
#  {'Parameter Index': 156,
#   'Estimate': 0.010448261,
#   'Standard Error': 54.990521722995126,
#   'Z-score': 0.00019000112813549977,
#   'P-value': 0.9998484010342377,
#   'Significant at 95%': False},
#  {'Parameter Index': 157,
#   'Estimate': -0.015391065,
#   'Standard Error': 26.001511411331975,
#   'Z-score': -0.0005919296214859612,
#   'P-value': 0.9995277085215148,
#   'Significant at 95%': False},
#  {'Parameter Index': 158,
#   'Estimate': -0.00462382,
#   'Standard Error': 26.834198116642778,
#   'Z-score': -0.0001723107228248001,
#   'P-value': 0.9998625159352776,
#   'Significant at 95%': False},
#  {'Parameter Index': 159,
#   'Estimate': 0.007222143,
#   'Standard Error': 55.09729820760752,
#   'Z-score': 0.00013107980312648484,
#   'P-value': 0.9998954134491518,
#   'Significant at 95%': False},
#  {'Parameter Index': 160,
#   'Estimate': 0.013747748,
#   'Standard Error': 194.3238477419488,
#   'Z-score': 7.074658178735228e-05,
#   'P-value': 0.9999435523947093,
#   'Significant at 95%': False},
#  {'Parameter Index': 161,
#   'Estimate': 0.004530169,
#   'Standard Error': 83.42728921110587,
#   'Z-score': 5.430080627819249e-05,
#   'P-value': 0.9999566742250527,
#   'Significant at 95%': False},
#  {'Parameter Index': 162,
#   'Estimate': 0.043088626,
#   'Standard Error': 10.86191213692146,
#   'Z-score': 0.00396694666402693,
#   'P-value': 0.9968348428047502,
#   'Significant at 95%': False},
#  {'Parameter Index': 163,
#   'Estimate': -0.009090304,
#   'Standard Error': 81.32654932232882,
#   'Z-score': -0.00011177536057341378,
#   'P-value': 0.999910816165706,
#   'Significant at 95%': False},
#  {'Parameter Index': 164,
#   'Estimate': -0.0021269147,
#   'Standard Error': 302.6866064148864,
#   'Z-score': -7.026788225150095e-06,
#   'P-value': 0.9999943934341631,
#   'Significant at 95%': False},
#  {'Parameter Index': 165,
#   'Estimate': -0.02612422,
#   'Standard Error': 25.48354526830339,
#   'Z-score': -0.0010251407355764389,
#   'P-value': 0.9991820561776981,
#   'Significant at 95%': False},
#  {'Parameter Index': 166,
#   'Estimate': -0.0040238383,
#   'Standard Error': 50.33944818046349,
#   'Z-score': -7.993409677802738e-05,
#   'P-value': 0.9999362218183669,
#   'Significant at 95%': False},
#  {'Parameter Index': 167,
#   'Estimate': -0.013982136,
#   'Standard Error': 31.61527008520324,
#   'Z-score': -0.0004422589389502448,
#   'P-value': 0.9996471284322377,
#   'Significant at 95%': False},
#  {'Parameter Index': 168,
#   'Estimate': -0.018689785,
#   'Standard Error': 76.54864874882612,
#   'Z-score': -0.00024415565079403614,
#   'P-value': 0.9998051919777342,
#   'Significant at 95%': False},
#  {'Parameter Index': 169,
#   'Estimate': -0.0006506462,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 170,
#   'Estimate': -0.008212305,
#   'Standard Error': 69.36690339015823,
#   'Z-score': -0.00011838937984442472,
#   'P-value': 0.9999055389418798,
#   'Significant at 95%': False},
#  {'Parameter Index': 171,
#   'Estimate': 0.0038411976,
#   'Standard Error': 110.30158891403656,
#   'Z-score': 3.482449909962793e-05,
#   'P-value': 0.9999722140698364,
#   'Significant at 95%': False},
#  {'Parameter Index': 172,
#   'Estimate': -0.005429531,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 173,
#   'Estimate': 0.024391972,
#   'Standard Error': 20.49701498581809,
#   'Z-score': 0.001190025549837718,
#   'P-value': 0.9990504972109318,
#   'Significant at 95%': False},
#  {'Parameter Index': 174,
#   'Estimate': 0.019207714,
#   'Standard Error': 77.65131089025681,
#   'Z-score': 0.0002473585301432959,
#   'P-value': 0.9998026364498285,
#   'Significant at 95%': False},
#  {'Parameter Index': 175,
#   'Estimate': 0.0021353597,
#   'Standard Error': 27.482636602397367,
#   'Z-score': 7.769850153156204e-05,
#   'P-value': 0.9999380055652929,
#   'Significant at 95%': False},
#  {'Parameter Index': 176,
#   'Estimate': 0.014564006,
#   'Standard Error': 45.802328117267336,
#   'Z-score': 0.000317975226515613,
#   'P-value': 0.9997462924803207,
#   'Significant at 95%': False},
#  {'Parameter Index': 177,
#   'Estimate': -0.0025433588,
#   'Standard Error': 59.126591753438404,
#   'Z-score': -4.3015481787637164e-05,
#   'P-value': 0.9999656786112168,
#   'Significant at 95%': False},
#  {'Parameter Index': 178,
#   'Estimate': 0.006415721,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 179,
#   'Estimate': 0.009522405,
#   'Standard Error': 23.54506616481068,
#   'Z-score': 0.00040443315751892097,
#   'P-value': 0.9996773090365358,
#   'Significant at 95%': False},
#  {'Parameter Index': 180,
#   'Estimate': -0.034629203,
#   'Standard Error': 70.30804235604431,
#   'Z-score': -0.0004925354514038346,
#   'P-value': 0.999607013583566,
#   'Significant at 95%': False},
#  {'Parameter Index': 181,
#   'Estimate': -0.0050073997,
#   'Standard Error': 44.28735801568479,
#   'Z-score': -0.00011306611945522874,
#   'P-value': 0.9999097862891291,
#   'Significant at 95%': False},
#  {'Parameter Index': 182,
#   'Estimate': -0.012507919,
#   'Standard Error': 126.79416415071859,
#   'Z-score': -9.864743622780989e-05,
#   'P-value': 0.9999212907337987,
#   'Significant at 95%': False},
#  {'Parameter Index': 183,
#   'Estimate': -0.0009898252,
#   'Standard Error': 209.75115203277883,
#   'Z-score': -4.719045508745385e-06,
#   'P-value': 0.9999962347464468,
#   'Significant at 95%': False},
#  {'Parameter Index': 184,
#   'Estimate': 0.002924579,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 185,
#   'Estimate': -0.012320488,
#   'Standard Error': 35.46572440761064,
#   'Z-score': -0.00034739140298974163,
#   'P-value': 0.9997228217685739,
#   'Significant at 95%': False},
#  {'Parameter Index': 186,
#   'Estimate': 0.006680928,
#   'Standard Error': 94.86650243781916,
#   'Z-score': 7.042452287160112e-05,
#   'P-value': 0.9999438093605453,
#   'Significant at 95%': False},
#  {'Parameter Index': 187,
#   'Estimate': 0.0063628233,
#   'Standard Error': 88.1621756924464,
#   'Z-score': 7.217180444803902e-05,
#   'P-value': 0.9999424152315557,
#   'Significant at 95%': False},
#  {'Parameter Index': 188,
#   'Estimate': -0.014176268,
#   'Standard Error': 159.0890698950308,
#   'Z-score': -8.910900126510607e-05,
#   'P-value': 0.999928901303756,
#   'Significant at 95%': False},
#  {'Parameter Index': 189,
#   'Estimate': 0.013532515,
#   'Standard Error': 194.2019169299418,
#   'Z-score': 6.968270394974581e-05,
#   'P-value': 0.9999444012464085,
#   'Significant at 95%': False},
#  {'Parameter Index': 190,
#   'Estimate': 0.011796846,
#   'Standard Error': 73.5320400513884,
#   'Z-score': 0.0001604313717700484,
#   'P-value': 0.9998719942859453,
#   'Significant at 95%': False},
#  {'Parameter Index': 191,
#   'Estimate': 0.025352972,
#   'Standard Error': 152.8768844875758,
#   'Z-score': 0.0001658391437874227,
#   'P-value': 0.9998676795082018,
#   'Significant at 95%': False},
#  {'Parameter Index': 192,
#   'Estimate': 0.0006959975,
#   'Standard Error': 54.97603884597308,
#   'Z-score': 1.2660015426189696e-05,
#   'P-value': 0.9999898987691522,
#   'Significant at 95%': False},
#  {'Parameter Index': 193,
#   'Estimate': 0.004214996,
#   'Standard Error': 87.99041569149182,
#   'Z-score': 4.790289911935664e-05,
#   'P-value': 0.9999617790163895,
#   'Significant at 95%': False},
#  {'Parameter Index': 194,
#   'Estimate': -0.036593255,
#   'Standard Error': 59.200444684387115,
#   'Z-score': -0.0006181246585340313,
#   'P-value': 0.9995068079097105,
#   'Significant at 95%': False},
#  {'Parameter Index': 195,
#   'Estimate': 0.0029970007,
#   'Standard Error': 3.943408503223043,
#   'Z-score': 0.0007600025965547221,
#   'P-value': 0.9993936057204149,
#   'Significant at 95%': False},
#  {'Parameter Index': 196,
#   'Estimate': -0.008980578,
#   'Standard Error': 117.25362406335427,
#   'Z-score': -7.659104682978846e-05,
#   'P-value': 0.9999388891862986,
#   'Significant at 95%': False},
#  {'Parameter Index': 197,
#   'Estimate': -0.018629419,
#   'Standard Error': 36.402600227338795,
#   'Z-score': -0.0005117606591202069,
#   'P-value': 0.9995916740890851,
#   'Significant at 95%': False},
#  {'Parameter Index': 198,
#   'Estimate': 0.024746599,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 199,
#   'Estimate': -0.0031402488,
#   'Standard Error': 182.28320949056712,
#   'Z-score': -1.72273070717106e-05,
#   'P-value': 0.9999862545976639,
#   'Significant at 95%': False},
#  {'Parameter Index': 200,
#   'Estimate': -0.006054601,
#   'Standard Error': 41.717353368576454,
#   'Z-score': -0.00014513387541401307,
#   'P-value': 0.9998841999219643,
#   'Significant at 95%': False},
#  {'Parameter Index': 201,
#   'Estimate': 0.0011136284,
#   'Standard Error': 114.76321592538804,
#   'Z-score': 9.703704950581567e-06,
#   'P-value': 0.9999922575636375,
#   'Significant at 95%': False},
#  {'Parameter Index': 202,
#   'Estimate': 0.015230675,
#   'Standard Error': 47.124521445084696,
#   'Z-score': 0.0003232006344231791,
#   'P-value': 0.9997421232082417,
#   'Significant at 95%': False},
#  {'Parameter Index': 203,
#   'Estimate': 0.0030722404,
#   'Standard Error': 153.11843287690783,
#   'Z-score': 2.00644712211318e-05,
#   'P-value': 0.9999839908681931,
#   'Significant at 95%': False},
#  {'Parameter Index': 204,
#   'Estimate': 0.00020790649,
#   'Standard Error': 24.57285654375623,
#   'Z-score': 8.460818817640922e-06,
#   'P-value': 0.9999932492432937,
#   'Significant at 95%': False},
#  {'Parameter Index': 205,
#   'Estimate': 0.009115036,
#   'Standard Error': 60.86818508351086,
#   'Z-score': 0.0001497504095638461,
#   'P-value': 0.9998805164606817,
#   'Significant at 95%': False},
#  {'Parameter Index': 206,
#   'Estimate': -0.034288194,
#   'Standard Error': 71.65743003947293,
#   'Z-score': -0.00047850158750649364,
#   'P-value': 0.9996182109855782,
#   'Significant at 95%': False},
#  {'Parameter Index': 207,
#   'Estimate': -0.0240062,
#   'Standard Error': 18.307198698464354,
#   'Z-score': -0.0013112983306226194,
#   'P-value': 0.9989537356072322,
#   'Significant at 95%': False},
#  {'Parameter Index': 208,
#   'Estimate': 0.006458319,
#   'Standard Error': 46.55679900771425,
#   'Z-score': 0.00013871913297160788,
#   'P-value': 0.999889318145869,
#   'Significant at 95%': False},
#  {'Parameter Index': 209,
#   'Estimate': 0.0010661145,
#   'Standard Error': 162.43480257556726,
#   'Z-score': 6.563338051635263e-06,
#   'P-value': 0.9999947632139012,
#   'Significant at 95%': False},
#  {'Parameter Index': 210,
#   'Estimate': -0.0035184163,
#   'Standard Error': 100.99784140249112,
#   'Z-score': -3.48365496192449e-05,
#   'P-value': 0.9999722044549129,
#   'Significant at 95%': False},
#  {'Parameter Index': 211,
#   'Estimate': -0.025299828,
#   'Standard Error': 68.1236576522014,
#   'Z-score': -0.00037138094711122765,
#   'P-value': 0.9997036808829352,
#   'Significant at 95%': False},
#  {'Parameter Index': 212,
#   'Estimate': -0.01254143,
#   'Standard Error': 60.355310204867784,
#   'Z-score': -0.00020779331641948535,
#   'P-value': 0.999834204922184,
#   'Significant at 95%': False},
#  {'Parameter Index': 213,
#   'Estimate': -0.0117300255,
#   'Standard Error': 110.14092332626377,
#   'Z-score': -0.00010650015605610756,
#   'P-value': 0.9999150251699205,
#   'Significant at 95%': False},
#  {'Parameter Index': 214,
#   'Estimate': 0.01846187,
#   'Standard Error': 26.054618423985197,
#   'Z-score': 0.0007085833969678542,
#   'P-value': 0.9994346322948291,
#   'Significant at 95%': False},
#  {'Parameter Index': 215,
#   'Estimate': 0.016620988,
#   'Standard Error': 28.933252028954755,
#   'Z-score': 0.0005744597257725467,
#   'P-value': 0.9995416474792127,
#   'Significant at 95%': False},
#  {'Parameter Index': 216,
#   'Estimate': -0.007608569,
#   'Standard Error': 62.27681144856548,
#   'Z-score': -0.00012217339086865347,
#   'P-value': 0.9999025197379274,
#   'Significant at 95%': False},
#  {'Parameter Index': 217,
#   'Estimate': 0.01076483,
#   'Standard Error': 56.30982371405025,
#   'Z-score': 0.0001911714351850838,
#   'P-value': 0.9998474672643285,
#   'Significant at 95%': False},
#  {'Parameter Index': 218,
#   'Estimate': 0.009378094,
#   'Standard Error': 78.10259111408473,
#   'Z-score': 0.00012007404738241382,
#   'P-value': 0.9999041947716707,
#   'Significant at 95%': False},
#  {'Parameter Index': 219,
#   'Estimate': 0.0035857984,
#   'Standard Error': 87.89416294604996,
#   'Z-score': 4.07967754952226e-05,
#   'P-value': 0.9999674488827108,
#   'Significant at 95%': False},
#  {'Parameter Index': 220,
#   'Estimate': -0.015370877,
#   'Standard Error': 56.10443149806204,
#   'Z-score': -0.0002739690439635987,
#   'P-value': 0.999781404332418,
#   'Significant at 95%': False},
#  {'Parameter Index': 221,
#   'Estimate': 0.006055496,
#   'Standard Error': 129.7723745496162,
#   'Z-score': 4.6662444055659364e-05,
#   'P-value': 0.9999627687563322,
#   'Significant at 95%': False},
#  {'Parameter Index': 222,
#   'Estimate': -0.0039453376,
#   'Standard Error': 123.06278974116405,
#   'Z-score': -3.2059549574284606e-05,
#   'P-value': 0.9999744201803729,
#   'Significant at 95%': False},
#  {'Parameter Index': 223,
#   'Estimate': 0.0145783955,
#   'Standard Error': 69.47373323000156,
#   'Z-score': 0.00020984039356093442,
#   'P-value': 0.9998325715909737,
#   'Significant at 95%': False},
#  {'Parameter Index': 224,
#   'Estimate': 0.00564414,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 225,
#   'Estimate': -0.00048216694,
#   'Standard Error': 184.90410387027043,
#   'Z-score': -2.607659497990143e-06,
#   'P-value': 0.9999979193887467,
#   'Significant at 95%': False},
#  {'Parameter Index': 226,
#   'Estimate': 0.016026214,
#   'Standard Error': 70.77391879126436,
#   'Z-score': 0.00022644236801993317,
#   'P-value': 0.9998193251321894,
#   'Significant at 95%': False},
#  {'Parameter Index': 227,
#   'Estimate': -0.0076261493,
#   'Standard Error': 156.58938281071437,
#   'Z-score': -4.8701573509343606e-05,
#   'P-value': 0.9999611417664254,
#   'Significant at 95%': False},
#  {'Parameter Index': 228,
#   'Estimate': -0.018754223,
#   'Standard Error': 127.56777021509043,
#   'Z-score': -0.0001470138055246251,
#   'P-value': 0.9998826999547696,
#   'Significant at 95%': False},
#  {'Parameter Index': 229,
#   'Estimate': -0.0040505407,
#   'Standard Error': 91.8460672733329,
#   'Z-score': -4.410140638633318e-05,
#   'P-value': 0.9999648121687461,
#   'Significant at 95%': False},
#  {'Parameter Index': 230,
#   'Estimate': -0.01219462,
#   'Standard Error': 32.89643370048261,
#   'Z-score': -0.00037069733930434446,
#   'P-value': 0.9997042263230125,
#   'Significant at 95%': False},
#  {'Parameter Index': 231,
#   'Estimate': 0.007692874,
#   'Standard Error': 200.49343550116288,
#   'Z-score': 3.836970484528636e-05,
#   'P-value': 0.999969385404909,
#   'Significant at 95%': False},
#  {'Parameter Index': 232,
#   'Estimate': -0.017357657,
#   'Standard Error': 32.4274474051086,
#   'Z-score': -0.0005352766906181786,
#   'P-value': 0.999572911013193,
#   'Significant at 95%': False},
#  {'Parameter Index': 233,
#   'Estimate': -0.0033363686,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 234,
#   'Estimate': 0.021435078,
#   'Standard Error': 221.2285714887438,
#   'Z-score': 9.689109362879504e-05,
#   'P-value': 0.9999226920924353,
#   'Significant at 95%': False},
#  {'Parameter Index': 235,
#   'Estimate': -0.019332474,
#   'Standard Error': 59.90184487655447,
#   'Z-score': -0.0003227358712815911,
#   'P-value': 0.9997424940355575,
#   'Significant at 95%': False},
#  {'Parameter Index': 236,
#   'Estimate': 0.019082652,
#   'Standard Error': 116.8003567146175,
#   'Z-score': 0.00016337837436172987,
#   'P-value': 0.9998696429181075,
#   'Significant at 95%': False},
#  {'Parameter Index': 237,
#   'Estimate': 0.015209537,
#   'Standard Error': 40.410832975495715,
#   'Z-score': 0.00037637276639872235,
#   'P-value': 0.9996996979876738,
#   'Significant at 95%': False},
#  {'Parameter Index': 238,
#   'Estimate': 0.009740738,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 239,
#   'Estimate': 0.00028406267,
#   'Standard Error': 326.12206621453873,
#   'Z-score': 8.710317356837995e-07,
#   'P-value': 0.9999993050172262,
#   'Significant at 95%': False},
#  {'Parameter Index': 240,
#   'Estimate': 0.020170446,
#   'Standard Error': 34.44701768316681,
#   'Z-score': 0.0005855498630041829,
#   'P-value': 0.9995327988314269,
#   'Significant at 95%': False},
#  {'Parameter Index': 241,
#   'Estimate': 0.010008798,
#   'Standard Error': 48.66647489079046,
#   'Z-score': 0.00020566104291106193,
#   'P-value': 0.9998359062302593,
#   'Significant at 95%': False},
#  {'Parameter Index': 242,
#   'Estimate': 0.005132843,
#   'Standard Error': 40.40857987841532,
#   'Z-score': 0.00012702358816879956,
#   'P-value': 0.999898649840415,
#   'Significant at 95%': False},
#  {'Parameter Index': 243,
#   'Estimate': 0.0151096815,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 244,
#   'Estimate': 0.004322888,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 245,
#   'Estimate': -0.007605677,
#   'Standard Error': 75.35466322316165,
#   'Z-score': -0.00010093173639937136,
#   'P-value': 0.9999194681259687,
#   'Significant at 95%': False},
#  {'Parameter Index': 246,
#   'Estimate': 0.00030811102,
#   'Standard Error': 60.53468202358248,
#   'Z-score': 5.089826338673964e-06,
#   'P-value': 0.9999959389061472,
#   'Significant at 95%': False},
#  {'Parameter Index': 247,
#   'Estimate': -0.010451292,
#   'Standard Error': 52.618480967173014,
#   'Z-score': -0.0001986239719521133,
#   'P-value': 0.9998415210004161,
#   'Significant at 95%': False},
#  {'Parameter Index': 248,
#   'Estimate': -0.004264234,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 249,
#   'Estimate': 0.030244753,
#   'Standard Error': 73.18372535148724,
#   'Z-score': 0.00041327156576741837,
#   'P-value': 0.9996702570076417,
#   'Significant at 95%': False},
#  {'Parameter Index': 250,
#   'Estimate': 0.0053267498,
#   'Standard Error': 44.1667562903099,
#   'Z-score': 0.0001206054101396832,
#   'P-value': 0.9999037708055336,
#   'Significant at 95%': False},
#  {'Parameter Index': 251,
#   'Estimate': -0.020246819,
#   'Standard Error': 71.0806541274748,
#   'Z-score': -0.00028484288601761414,
#   'P-value': 0.9997727282620654,
#   'Significant at 95%': False},
#  {'Parameter Index': 252,
#   'Estimate': 0.02117034,
#   'Standard Error': 34.46337567860451,
#   'Z-score': 0.0006142851668347507,
#   'P-value': 0.999509871380277,
#   'Significant at 95%': False},
#  {'Parameter Index': 253,
#   'Estimate': 0.021359578,
# ...
#  {'Parameter Index': 915,
#   'Estimate': -0.006433006,
#   'Standard Error': 16.690756566995617,
#   'Z-score': -0.00038542326613806295,
#   'P-value': 0.9996924767341882,
#   'Significant at 95%': False},
#  {'Parameter Index': 916,
#   'Estimate': 0.005276353,
#   'Standard Error': 38.150286018464335,
#   'Z-score': 0.0001383044178462618,
#   'P-value': 0.9998896490406615,
#   'Significant at 95%': False},
#  {'Parameter Index': 917,
#   'Estimate': -0.01090249,
#   'Standard Error': 30.465863948493457,
#   'Z-score': -0.00035785919460359407,
#   'P-value': 0.9997144696797788,
#   'Significant at 95%': False},
#  {'Parameter Index': 918,
#   'Estimate': 0.006557486,
#   'Standard Error': 7.747012583178073,
#   'Z-score': 0.0008464535134830645,
#   'P-value': 0.9993246278908035,
#   'Significant at 95%': False},
#  {'Parameter Index': 919,
#   'Estimate': 0.007521896,
#   'Standard Error': 24.45443993299068,
#   'Z-score': 0.00030758815896111274,
#   'P-value': 0.999754580160749,
#   'Significant at 95%': False},
#  {'Parameter Index': 920,
#   'Estimate': -0.01774747,
#   'Standard Error': 5.863526890005278,
#   'Z-score': -0.003026756690864516,
#   'P-value': 0.9975850012544567,
#   'Significant at 95%': False},
#  {'Parameter Index': 921,
#   'Estimate': 0.013776293,
#   'Standard Error': 57.104082770888574,
#   'Z-score': 0.0002412488276835406,
#   'P-value': 0.9998075112869467,
#   'Significant at 95%': False},
#  {'Parameter Index': 922,
#   'Estimate': 0.005543381,
#   'Standard Error': 43.32616824969824,
#   'Z-score': 0.00012794533187831294,
#   'P-value': 0.9998979143953459,
#   'Significant at 95%': False},
#  {'Parameter Index': 923,
#   'Estimate': -0.007338328,
#   'Standard Error': 10.726236799982827,
#   'Z-score': -0.0006841474748493233,
#   'P-value': 0.9994541293350887,
#   'Significant at 95%': False},
#  {'Parameter Index': 924,
#   'Estimate': -0.015282933,
#   'Standard Error': 9.264213948740974,
#   'Z-score': -0.0016496739770351823,
#   'P-value': 0.9986837512003772,
#   'Significant at 95%': False},
#  {'Parameter Index': 925,
#   'Estimate': 0.011054515,
#   'Standard Error': 46.41155148354635,
#   'Z-score': 0.00023818455867004312,
#   'P-value': 0.9998099562198124,
#   'Significant at 95%': False},
#  {'Parameter Index': 926,
#   'Estimate': 0.010917683,
#   'Standard Error': 5.3255495154714145,
#   'Z-score': 0.0020500575762699277,
#   'P-value': 0.9983642918568789,
#   'Significant at 95%': False},
#  {'Parameter Index': 927,
#   'Estimate': -0.010553798,
#   'Standard Error': 24.867898056348512,
#   'Z-score': -0.0004243944415023592,
#   'P-value': 0.9996613822375995,
#   'Significant at 95%': False},
#  {'Parameter Index': 928,
#   'Estimate': -0.0124666365,
#   'Standard Error': 55.52345873200703,
#   'Z-score': -0.0002245291768750166,
#   'P-value': 0.9998208516378269,
#   'Significant at 95%': False},
#  {'Parameter Index': 929,
#   'Estimate': -0.0060530826,
#   'Standard Error': 64.95161459624202,
#   'Z-score': -9.319372093468547e-05,
#   'P-value': 0.9999256421690101,
#   'Significant at 95%': False},
#  {'Parameter Index': 930,
#   'Estimate': -0.044651195,
#   'Standard Error': 10.079070772632393,
#   'Z-score': -0.004430090473037924,
#   'P-value': 0.9964653107703996,
#   'Significant at 95%': False},
#  {'Parameter Index': 931,
#   'Estimate': 0.0056880796,
#   'Standard Error': 55.013691210169796,
#   'Z-score': 0.00010339389173303108,
#   'P-value': 0.9999175036102519,
#   'Significant at 95%': False},
#  {'Parameter Index': 932,
#   'Estimate': 0.0027845202,
#   'Standard Error': 58.37965582564549,
#   'Z-score': 4.769675523841793e-05,
#   'P-value': 0.9999619434954092,
#   'Significant at 95%': False},
#  {'Parameter Index': 933,
#   'Estimate': 0.01390605,
#   'Standard Error': 21.81645604193723,
#   'Z-score': 0.0006374110220009055,
#   'P-value': 0.9994914196210987,
#   'Significant at 95%': False},
#  {'Parameter Index': 934,
#   'Estimate': -0.0020660046,
#   'Standard Error': 23.005953239881126,
#   'Z-score': -8.98030407229969e-05,
#   'P-value': 0.9999283475403902,
#   'Significant at 95%': False},
#  {'Parameter Index': 935,
#   'Estimate': 0.0042528263,
#   'Standard Error': 5.425224452177329,
#   'Z-score': 0.0007838986878439404,
#   'P-value': 0.999374539403793,
#   'Significant at 95%': False},
#  {'Parameter Index': 936,
#   'Estimate': 0.0138371335,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 937,
#   'Estimate': -0.0014110424,
#   'Standard Error': 61.6194453165591,
#   'Z-score': -2.2899303974073426e-05,
#   'P-value': 0.9999817289989075,
#   'Significant at 95%': False},
#  {'Parameter Index': 938,
#   'Estimate': 0.0009005202,
#   'Standard Error': 19.01396698759273,
#   'Z-score': 4.736098400682243e-05,
#   'P-value': 0.9999622114020907,
#   'Significant at 95%': False},
#  {'Parameter Index': 939,
#   'Estimate': -0.0022668068,
#   'Standard Error': 45.84909121198441,
#   'Z-score': -4.944060445329155e-05,
#   'P-value': 0.9999605521050461,
#   'Significant at 95%': False},
#  {'Parameter Index': 940,
#   'Estimate': 0.00026564283,
#   'Standard Error': 64.74935627577857,
#   'Z-score': 4.102632694112375e-06,
#   'P-value': 0.9999967265727148,
#   'Significant at 95%': False},
#  {'Parameter Index': 941,
#   'Estimate': -0.0067060296,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 942,
#   'Estimate': -0.01321828,
#   'Standard Error': 35.64811708596851,
#   'Z-score': -0.00037079882497277367,
#   'P-value': 0.99970414534917,
#   'Significant at 95%': False},
#  {'Parameter Index': 943,
#   'Estimate': 0.0077312756,
#   'Standard Error': 5.501006488972428,
#   'Z-score': 0.0014054292879813826,
#   'P-value': 0.9988786300389805,
#   'Significant at 95%': False},
#  {'Parameter Index': 944,
#   'Estimate': -0.00574689,
#   'Standard Error': 23.13375870502587,
#   'Z-score': -0.0002484200657885057,
#   'P-value': 0.9998017894669524,
#   'Significant at 95%': False},
#  {'Parameter Index': 945,
#   'Estimate': -0.002757014,
#   'Standard Error': 40.68527864072074,
#   'Z-score': -6.776441259221203e-05,
#   'P-value': 0.9999459318214621,
#   'Significant at 95%': False},
#  {'Parameter Index': 946,
#   'Estimate': -0.0065374393,
#   'Standard Error': 29.625368268555714,
#   'Z-score': -0.00022067031344041765,
#   'P-value': 0.9998239305653074,
#   'Significant at 95%': False},
#  {'Parameter Index': 947,
#   'Estimate': -0.008393286,
#   'Standard Error': 18.18128900666384,
#   'Z-score': -0.0004616441547664709,
#   'P-value': 0.99963166126941,
#   'Significant at 95%': False},
#  {'Parameter Index': 948,
#   'Estimate': 0.033617236,
#   'Standard Error': 27.98309402650493,
#   'Z-score': 0.0012013409127781284,
#   'P-value': 0.9990414688639955,
#   'Significant at 95%': False},
#  {'Parameter Index': 949,
#   'Estimate': 0.00082008244,
#   'Standard Error': 25.408657690089008,
#   'Z-score': 3.2275708843627084e-05,
#   'P-value': 0.9999742477102291,
#   'Significant at 95%': False},
#  {'Parameter Index': 950,
#   'Estimate': 0.00882837,
#   'Standard Error': 28.52435751416221,
#   'Z-score': 0.00030950284844105517,
#   'P-value': 0.999753052459647,
#   'Significant at 95%': False},
#  {'Parameter Index': 951,
#   'Estimate': 0.0042976723,
#   'Standard Error': 68.90898408273439,
#   'Z-score': 6.23673728827028e-05,
#   'P-value': 0.9999502380361114,
#   'Significant at 95%': False},
#  {'Parameter Index': 952,
#   'Estimate': 0.0013280814,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 953,
#   'Estimate': 0.0031545607,
#   'Standard Error': 16.65559619466839,
#   'Z-score': 0.0001893994459204958,
#   'P-value': 0.9998488811071788,
#   'Significant at 95%': False},
#  {'Parameter Index': 954,
#   'Estimate': -0.002483799,
#   'Standard Error': 16.286596519823863,
#   'Z-score': -0.00015250570531541235,
#   'P-value': 0.9998783180527662,
#   'Significant at 95%': False},
#  {'Parameter Index': 955,
#   'Estimate': -0.009975125,
#   'Standard Error': 19.929230011952455,
#   'Z-score': -0.0005005273698910919,
#   'P-value': 0.9996006369559798,
#   'Significant at 95%': False},
#  {'Parameter Index': 956,
#   'Estimate': 0.013120674,
#   'Standard Error': 15.83394067069496,
#   'Z-score': 0.0008286423367205345,
#   'P-value': 0.9993388391487672,
#   'Significant at 95%': False},
#  {'Parameter Index': 957,
#   'Estimate': -0.010986267,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 958,
#   'Estimate': -0.010997234,
#   'Standard Error': 28.136583707824517,
#   'Z-score': -0.0003908517830930029,
#   'P-value': 0.999688145404648,
#   'Significant at 95%': False},
#  {'Parameter Index': 959,
#   'Estimate': -0.021224706,
#   'Standard Error': 57.4965234450871,
#   'Z-score': -0.00036914763242445136,
#   'P-value': 0.999705462810121,
#   'Significant at 95%': False},
#  {'Parameter Index': 960,
#   'Estimate': 0.0017941411,
#   'Standard Error': 83.36762746725917,
#   'Z-score': 2.1520837160480746e-05,
#   'P-value': 0.9999828288562955,
#   'Significant at 95%': False},
#  {'Parameter Index': 961,
#   'Estimate': -0.0034689123,
#   'Standard Error': 49.35949078731796,
#   'Z-score': -7.027852743880789e-05,
#   'P-value': 0.9999439258480467,
#   'Significant at 95%': False},
#  {'Parameter Index': 962,
#   'Estimate': 0.024413288,
#   'Standard Error': 8.187241367597617,
#   'Z-score': 0.0029818697829329436,
#   'P-value': 0.9976208156636455,
#   'Significant at 95%': False},
#  {'Parameter Index': 963,
#   'Estimate': -0.008531647,
#   'Standard Error': 8.03180336487862,
#   'Z-score': -0.0010622330273084774,
#   'P-value': 0.9991524608269209,
#   'Significant at 95%': False},
#  {'Parameter Index': 964,
#   'Estimate': 0.008767679,
#   'Standard Error': 49.427898064304486,
#   'Z-score': 0.00017738321225556247,
#   'P-value': 0.9998584686743379,
#   'Significant at 95%': False},
#  {'Parameter Index': 965,
#   'Estimate': 0.017568158,
#   'Standard Error': 35.00301835685185,
#   'Z-score': 0.0005019040874332911,
#   'P-value': 0.9995995384944463,
#   'Significant at 95%': False},
#  {'Parameter Index': 966,
#   'Estimate': -0.018133147,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 967,
#   'Estimate': 0.0030507338,
#   'Standard Error': 22.159620472843983,
#   'Z-score': 0.00013767085167671543,
#   'P-value': 0.9998901545533216,
#   'Significant at 95%': False},
#  {'Parameter Index': 968,
#   'Estimate': -0.00041928058,
#   'Standard Error': 20.358810025375384,
#   'Z-score': -2.0594552361273104e-05,
#   'P-value': 0.9999835679246354,
#   'Significant at 95%': False},
#  {'Parameter Index': 969,
#   'Estimate': 0.001912396,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 970,
#   'Estimate': -0.018471371,
#   'Standard Error': 8.34520015514464,
#   'Z-score': -0.002213412625110937,
#   'P-value': 0.9982339536817724,
#   'Significant at 95%': False},
#  {'Parameter Index': 971,
#   'Estimate': 0.0027812768,
#   'Standard Error': 44.678400327337876,
#   'Z-score': 6.225103861319276e-05,
#   'P-value': 0.9999503308574287,
#   'Significant at 95%': False},
#  {'Parameter Index': 972,
#   'Estimate': -0.006405743,
#   'Standard Error': 27.60088470309372,
#   'Z-score': -0.00023208469249758369,
#   'P-value': 0.9998148232087198,
#   'Significant at 95%': False},
#  {'Parameter Index': 973,
#   'Estimate': -0.0046467083,
#   'Standard Error': 56.95624361240045,
#   'Z-score': -8.158382580702146e-05,
#   'P-value': 0.9999349055250495,
#   'Significant at 95%': False},
#  {'Parameter Index': 974,
#   'Estimate': 0.035657614,
#   'Standard Error': 8.689834208375272,
#   'Z-score': 0.004103371090228782,
#   'P-value': 0.9967259927476313,
#   'Significant at 95%': False},
#  {'Parameter Index': 975,
#   'Estimate': 0.011448693,
#   'Standard Error': 9.091180845568257,
#   'Z-score': 0.0012593186359610427,
#   'P-value': 0.9989952093688155,
#   'Significant at 95%': False},
#  {'Parameter Index': 976,
#   'Estimate': -0.003942634,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 977,
#   'Estimate': -0.004445813,
#   'Standard Error': 48.762281098276645,
#   'Z-score': -9.117319843235273e-05,
#   'P-value': 0.9999272543127127,
#   'Significant at 95%': False},
#  {'Parameter Index': 978,
#   'Estimate': 0.0044840127,
#   'Standard Error': 17.020272596869518,
#   'Z-score': 0.0002634512871311935,
#   'P-value': 0.9997897962879059,
#   'Significant at 95%': False},
#  {'Parameter Index': 979,
#   'Estimate': 0.019370671,
#   'Standard Error': 16.522323060648755,
#   'Z-score': 0.0011723939358031293,
#   'P-value': 0.9990645651937375,
#   'Significant at 95%': False},
#  {'Parameter Index': 980,
#   'Estimate': 0.01394336,
#   'Standard Error': 22.71856838988235,
#   'Z-score': 0.000613742906147331,
#   'P-value': 0.999510304041626,
#   'Significant at 95%': False},
#  {'Parameter Index': 981,
#   'Estimate': 0.009613455,
#   'Standard Error': 103.8925683139954,
#   'Z-score': 9.253265588888105e-05,
#   'P-value': 0.9999261696226016,
#   'Significant at 95%': False},
#  {'Parameter Index': 982,
#   'Estimate': -0.012169538,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 983,
#   'Estimate': -0.011612039,
#   'Standard Error': 39.705301516935755,
#   'Z-score': -0.00029245563226481484,
#   'P-value': 0.9997666541696224,
#   'Significant at 95%': False},
#  {'Parameter Index': 984,
#   'Estimate': 0.00051531784,
#   'Standard Error': 7.226130392189484,
#   'Z-score': 7.131311053235132e-05,
#   'P-value': 0.9999431003701715,
#   'Significant at 95%': False},
#  {'Parameter Index': 985,
#   'Estimate': -0.011846547,
#   'Standard Error': 6.8105183504376,
#   'Z-score': -0.0017394486594768705,
#   'P-value': 0.998612121470174,
#   'Significant at 95%': False},
#  {'Parameter Index': 986,
#   'Estimate': -0.0074224425,
#   'Standard Error': 58.58222438877397,
#   'Z-score': -0.00012670127543670605,
#   'P-value': 0.9998989070087656,
#   'Significant at 95%': False},
#  {'Parameter Index': 987,
#   'Estimate': -0.006053361,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 988,
#   'Estimate': 0.010027835,
#   'Standard Error': 10.663504472749082,
#   'Z-score': 0.0009403883283604498,
#   'P-value': 0.9992496787822307,
#   'Significant at 95%': False},
#  {'Parameter Index': 989,
#   'Estimate': -0.005927688,
#   'Standard Error': 34.60677649492499,
#   'Z-score': -0.00017128691478614355,
#   'P-value': 0.9998633328158928,
#   'Significant at 95%': False},
#  {'Parameter Index': 990,
#   'Estimate': -0.0009917115,
#   'Standard Error': 30.99984736169683,
#   'Z-score': -3.19908513691383e-05,
#   'P-value': 0.9999744749936099,
#   'Significant at 95%': False},
#  {'Parameter Index': 991,
#   'Estimate': -0.0056690164,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 992,
#   'Estimate': -0.009260816,
#   'Standard Error': 14.901534769811896,
#   'Z-score': -0.0006214672321557922,
#   'P-value': 0.9995041409223366,
#   'Significant at 95%': False},
#  {'Parameter Index': 993,
#   'Estimate': 0.0031537593,
#   'Standard Error': 49.03031694060215,
#   'Z-score': 6.432263718570046e-05,
#   'P-value': 0.9999486779609148,
#   'Significant at 95%': False},
#  {'Parameter Index': 994,
#   'Estimate': -0.017768854,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 995,
#   'Estimate': 0.0036532825,
#   'Standard Error': 56.34951788249057,
#   'Z-score': 6.483254284600754e-05,
#   'P-value': 0.9999482711150618,
#   'Significant at 95%': False},
#  {'Parameter Index': 996,
#   'Estimate': 0.016243745,
#   'Standard Error': 13.54038139291869,
#   'Z-score': 0.001199651927828085,
#   'P-value': 0.9990428164780394,
#   'Significant at 95%': False},
#  {'Parameter Index': 997,
#   'Estimate': -0.002317618,
#   'Standard Error': 7.75559708557906,
#   'Z-score': -0.00029883168084125403,
#   'P-value': 0.9997615668191266,
#   'Significant at 95%': False},
#  {'Parameter Index': 998,
#   'Estimate': 0.011843168,
#   'Standard Error': nan,
#   'Z-score': nan,
#   'P-value': nan,
#   'Significant at 95%': False},
#  {'Parameter Index': 999,
#   'Estimate': -0.008011825,
#   'Standard Error': 151.4022587903783,
#   'Z-score': -5.2917475912972695e-05,
#   'P-value': 0.999957777962992,
#   'Significant at 95%': False},
#  ...]

# %%
def test_coefficients_significance(theta_hat, fisher_matrix, confidence_level=0.95):
    """
    Test the statistical significance of regression coefficients using the Fisher information matrix.

    Parameters:
    - theta_hat (numpy array): Estimated parameters (shape: p,)
    - fisher_matrix (numpy array): Fisher information matrix (shape: p, p)
    - confidence_level (float): Desired confidence level (default: 0.95)

    Returns:
    - results (list of dict): Each dict contains parameter index, estimate, standard error, z-score, p-value, and significance
    """
    # Step 1: Compute Covariance Matrix
    try:
        cov_matrix = np.linalg.inv(fisher_matrix)
    except np.linalg.LinAlgError:
        # Regularize the Fisher information matrix if it's singular
        print("Fisher information matrix is singular or ill-conditioned. Adding a small value to the diagonal for regularization.")
        regularization_term = 1e-8 * np.eye(fisher_matrix.shape[0])
        cov_matrix = np.linalg.inv(fisher_matrix + regularization_term)

    # Step 2: Compute Standard Errors
    standard_errors = np.sqrt(np.diag(cov_matrix))

    # Avoid division by zero in standard errors
    standard_errors = np.where(standard_errors == 0, 1e-8, standard_errors)

    # Step 3: Compute Z-scores
    z_scores = theta_hat / standard_errors

    # Step 4: Compute P-values
    p_values = 2 * (1 - norm.cdf(np.abs(z_scores)))

    # Step 5: Assess Significance
    alpha = 1 - confidence_level
    significant = p_values < alpha

    

    # Compile Results
    results = []
    for idx, (theta, se, z, p, sig) in enumerate(zip(theta_hat, standard_errors, z_scores, p_values, significant)):
        result = {
            'Parameter Index': idx,
            'Estimate': theta,
            'Standard Error': se,
            'Z-score': z,
            'P-value': p,
            f'Significant at {int(confidence_level*100)}%': sig
        }
        results.append(result)

    return results

results=test_coefficients_significance(theta_hat, fisher_matrix, confidence_level=0.95)
# Out:
# Fisher information matrix is singular or ill-conditioned. Adding a small value to the diagonal for regularization.
# /tmp/ipykernel_1677307/1363067821.py:23: RuntimeWarning: invalid value encountered in sqrt
#   standard_errors = np.sqrt(np.diag(cov_matrix))

# %%
sig=[r[f'Significant at {int(0.95*100)}%'] for r in results]

np.where(sig==True)
# Out:
# /tmp/ipykernel_1677307/871683672.py:3: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   np.where(sig==True)
# (array([], dtype=int64),)
